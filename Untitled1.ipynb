# %% [markdown]
# # Reservation Cancellation Prediction
#
#
#    Predict the status of the reservation
#
#    The data reached 18137 rows and 18 columns. Before moving on to building a model, we calculated the correlation between some of the columns with each other and with the target of the regression (booking_status) as seen in the figure below.
#
#
#
# ![image.png](attachment:image.png)
